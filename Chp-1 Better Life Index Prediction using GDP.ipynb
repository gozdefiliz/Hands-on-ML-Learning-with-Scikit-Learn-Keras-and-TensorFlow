# %%
def prepare_country_stats(oecd_bli, gdp_per_capita):
    oecd_bli = oecd_bli[oecd_bli["INEQUALITY"]=="TOT"]
    oecd_bli = oecd_bli.pivot(index="Country", columns="Indicator", values="Value")
    gdp_per_capita.rename(columns={"2015": "GDP per capita"}, inplace=True)
    gdp_per_capita.set_index("Country", inplace=True)
    full_country_stats = pd.merge(left=oecd_bli, right=gdp_per_capita,
                                  left_index=True, right_index=True)
    full_country_stats.sort_values(by="GDP per capita", inplace=True)
    remove_indices = [0, 1, 6, 8, 33, 34, 35]
    keep_indices = list(set(range(36)) - set(remove_indices))
    return full_country_stats[["GDP per capita", 'Life satisfaction']].iloc[keep_indices]

# %%
import os
datapath = os.path.join("datasets", "lifesat", "")

# %%
# To plot pretty figures directly within Jupyter
# %matplotlib inline
import matplotlib as mpl
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
#this is the data used in the book
# Download the data
import urllib
DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml2/master/"
os.makedirs(datapath, exist_ok=True)
for filename in ("oecd_bli_2015.csv", "gdp_per_capita.csv"):
    print("Downloading", filename)
    url = DOWNLOAD_ROOT + "datasets/lifesat/" + filename
    urllib.request.urlretrieve(url, datapath + filename)

# %%
# Code example
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model

# Load the data
oecd_bli = pd.read_csv(datapath + "oecd_bli_2015.csv", thousands=',')
gdp_per_capita = pd.read_csv(datapath + "gdp_per_capita.csv",thousands=',',delimiter='\t',
                             encoding='latin1', na_values="n/a")

# Prepare the data
country_stats = prepare_country_stats(oecd_bli, gdp_per_capita)
X = np.c_[country_stats["GDP per capita"]]
y = np.c_[country_stats["Life satisfaction"]]

# Visualize the data
country_stats.plot(kind='scatter', x="GDP per capita", y='Life satisfaction')
plt.show()

# Select a linear model
model = sklearn.linear_model.LinearRegression()

# Train the model
model.fit(X, y)

# Make a prediction for Cyprus
X_new = [[22587]]  # Cyprus' GDP per capita
print(model.predict(X_new)) # outputs [[ 5.96242338]]
# Out:
# [[5.96242338]]

# %%
#Now I will make the prediction with the new data

# %%
cd /Users/gozdefiliz/Desktop/Hands-on Machine Learning with Scikit-Learn, Keras and TensorFlow/Chapter_1
# Out:
# /Users/gozdefiliz/Desktop/Hands-on Machine Learning with Scikit-Learn, Keras and TensorFlow/Chapter_1

# %%
oecd_bli_19 = pd.read_csv("bli_2019.csv", thousands=',')
oecd_bli_19 = oecd_bli_19[oecd_bli_19["INEQUALITY"]=="TOT"]
oecd_bli_19 = oecd_bli_19.pivot(index="Country", columns="Indicator", values="Value")
oecd_bli_19.head(2)
# Out:
# Indicator  Air pollution  Dwellings without basic facilities  \
# Country
# Australia            5.0                                 NaN
# Austria             16.0                                 0.9
#
# Indicator  Educational attainment  Employees working very long hours  \
# Country
# Australia                    81.0                              13.04
# Austria                      85.0                               6.66
#
# Indicator  Employment rate  Feeling safe walking alone at night  \
# Country
# Australia             73.0                                 63.5
# Austria               72.0                                 80.6
#
# Indicator  Homicide rate  Household net adjusted disposable income  \
# Country
# Australia            1.1                                   32759.0
# Austria              0.5                                   33541.0
#
# Indicator  Household net wealth  Housing expenditure         ...          \
# ...

# %%
oecd_bli_19["Life satisfaction"].head()
# Out:
# Country
# Australia    7.3
# Austria      7.1
# Belgium      6.9
# Brazil       6.4
# Canada       7.4
# Name: Life satisfaction, dtype: float64

# %%
gdp_per_capita_19 = pd.read_csv("gdp_2019.csv", thousands=',', delimiter='\t', encoding='latin1', na_values="n/a")
gdp_per_capita_19.rename(columns={"2019": "GDP per capita"}, inplace=True)
gdp_per_capita_19.set_index("Country", inplace=True)
gdp_per_capita_19.head(2)
# Out:
#                                             Subject Descriptor         Units  \
# Country
# Afghanistan  Gross domestic product per capita, current prices  U.S. dollars
# Albania      Gross domestic product per capita, current prices  U.S. dollars
#
#              Scale                      Country/Series-specific Notes  \
# Country
# Afghanistan  Units  See notes for:  Gross domestic product, curren...
# Albania      Units  See notes for:  Gross domestic product, curren...
#
#              GDP per capita  Estimates Start After
# Country
# Afghanistan         513.108                 2016.0
# Albania            5372.742                 2018.0

# %%
full_country_stats_19 = pd.merge(left=oecd_bli_19, right=gdp_per_capita_19, left_index=True, right_index=True)
full_country_stats_19.sort_values(by="GDP per capita", inplace=True)
full_country_stats_19
# Out:
#                  Air pollution  Dwellings without basic facilities  \
# Country
# South Africa              22.0                                37.0
# Colombia                  10.0                                23.9
# Brazil                    10.0                                 6.7
# Turkey                    20.0                                 8.0
# Mexico                    16.0                                25.5
# Russia                    15.0                                14.8
# Poland                    22.0                                 3.0
# Chile                     16.0                                 9.4
# Hungary                   19.0                                 4.7
# Latvia                    11.0                                13.9
# Lithuania                 14.0                                13.6
# Slovak Republic           21.0                                 1.2
# Greece                    18.0                                 0.5
# ...

# %%
# Prepare the data
remove_indices = [0, 1, 6, 8, 33, 34, 35]
keep_indices = list(set(range(36)) - set(remove_indices))
country_stats_19=full_country_stats_19[["GDP per capita", 'Life satisfaction']].iloc[keep_indices]


X = np.c_[country_stats_19["GDP per capita"]]
y = np.c_[country_stats_19["Life satisfaction"]]

# Visualize the data
country_stats_19.plot(kind='scatter', x="GDP per capita", y='Life satisfaction')
plt.show()

# Select a linear model
model = sklearn.linear_model.LinearRegression()

# Train the model
model.fit(X, y)

# Make a prediction for Cyprus
X_new = [[719690]]  # Cyprus' GDP per capita
print(model.predict(X_new))
# Out:
# [[30.11910219]]
